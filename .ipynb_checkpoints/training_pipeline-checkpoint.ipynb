# %% [markdown]
# # Train Model

# %% [markdown]
# ## Set parameters that will control the execution

# %%
DATA_DIR = "../_DATA/CarND/p3_behavioral_cloning/set_000/"
image_dir = "IMG/"
driving_data_csv = "driving_log_original.csv"
YIELD_BATCH_SIZE = 256
RUN_EPOCHS = 5 

should_retrain_existing_model = False
SAVED_MODEL = "model_epoch_5_val_acc_0.543157893482.h5"
RUN_EPOCHS_PREVIOUSLY = 0

# %%
import DataHelper
# Out:
# Using TensorFlow backend.

# %% [markdown]
# # Allocate only a fraction of memory to TensorFlow GPU process

# %%
# https://github.com/aymericdamien/TensorFlow-Examples/issues/38#issuecomment-265599695
import tensorflow as tf

# Running out of GPU memory on Mac
# InternalError: Dst tensor is not initialized.
gpu_options = tf.GPUOptions(per_process_gpu_memory_fraction=0.8) # try range from 0.3 to 0.9
sess = tf.Session(config=tf.ConfigProto(log_device_placement=True, gpu_options=gpu_options))

#### Show available CPU and GPU(s)
from tensorflow.python.client import device_lib
def get_available_CPU_GPU():
    devices = device_lib.list_local_devices()
    #return [x.name for x in devices if x.device_type == 'CPU']
    return [x.name for x in devices ]

print(get_available_CPU_GPU())
# Out:
# ['/cpu:0']

# %% [markdown]
# # Fetch data from CSV file

# %%
from  DataHelper import read_csv
csv_path = DATA_DIR + driving_data_csv
print("csv_path", csv_path)
headers, data = read_csv(DATA_DIR + driving_data_csv)
# Out:
# csv_path ../_DATA/CarND/p3_behavioral_cloning/set_000/driving_log_original.csv
# Number of imported CSV rows: 8037

# %% [markdown]
# # Split data into training, testing and validation sets

# %%
from DataHelper import split_random
training, testing, validation = split_random(data, percent_train=75, percent_test=15) 

print("training", training.shape, type(training) )
print("testing", testing.shape, type(training))
print("validation", validation.shape, type(training))
# Out:
# percent_validation 10
# training (6027, 7) <class 'numpy.ndarray'>
# testing (1206, 7) <class 'numpy.ndarray'>
# validation (803, 7) <class 'numpy.ndarray'>

# %% [markdown]
# # Fetch and visualize training steering angles
#
# I would like to train a car on the set that has a nice bell curve distribution of values:
# - I can drive the car on the track backwards
# - I can flip each image (and value)

# %% [markdown]
# # Remove zero-steering angles from training set

# %%
import numpy as np
from DataHelper import plot_histogram, get_steering_values, find_nearest

# %%
def remove_zeros(training):
    
    print("len(training)", len(training))
    indexes_to_keep = []
    
    steering_angles = get_steering_values(training)
    plot_histogram("steering values", steering_angles, change_step=0.01)

    for index in range (len(steering_angles)):
        angle = steering_angles[index]
        if angle != 0: 
            indexes_to_keep.append(index)

    print("len(indexes_to_keep)", len(indexes_to_keep))

    training_to_keep = []
    for index in indexes_to_keep:
        training_to_keep.append(training[index])

    training = training_to_keep
    # release the memory
    training_to_keep = []
    indexes_to_keep = []

    print("len(training)", len(training))

    steering_angles = get_steering_values(training)
    plot_histogram("steering values", steering_angles, change_step=0.01)
    return training

training = remove_zeros(training)
# Out:
# len(training) 6027
# min_value -0.942695 max_value 0.731557
# spread 1.67425 in 168 bins
# len(indexes_to_keep) 2765
# len(training) 2765
# min_value -0.942695 max_value 0.731557
# spread 1.67425 in 168 bins

# %% [markdown]
# # Test method that extracts image names

# %%
from DataHelper import get_image_center_values

# TEST THE METHOD
image_names = get_image_center_values(training[0:10]) # process only first few
print("image count:", image_names.shape[0], "path:", image_names[1])
# Out:
# image count: 10 path: IMG/center_2016_12_01_13_42_24_553.jpg

# %% [markdown]
# # Create a list of image paths

# %%
from generator import build_image_paths

image_paths = build_image_paths(DATA_DIR, image_names)
print(image_paths[1]) 
print("found paths:", len(image_paths) )
# Out:
# ../_DATA/CarND/p3_behavioral_cloning/set_000/IMG/center_2016_12_01_13_42_24_553.jpg
# found paths: 10

# %% [markdown]
# # Read actual images

# %%
from generator import read_images

training_features = read_images(image_paths)

print ("image_paths[2]", image_paths[2] )
print ("training_features count", len(training_features) )

sample_image = training_features[2]
print ("sample_image  ", sample_image.shape)

import matplotlib.pyplot as plt
plt.imshow(sample_image) # cmap='gray' , cmap='rainbow'
plt.show()

#print(sample_image[0][0:15])
# Out:
# image_paths[2] ../_DATA/CarND/p3_behavioral_cloning/set_000/IMG/center_2016_12_01_13_35_16_909.jpg
# training_features count 10
# sample_image   (160, 320, 3)

# %% [markdown]
# # Import Keras (layer above TensorFlow)
#
# https://keras.io/layers/convolutional/

# %%
import cv2, numpy as np
from DataHelper import mean_pred, false_rates

# %% [markdown]
# # Build a Convolutional Neural Network

# %% [markdown]
# ## Minimal Model

# %%
from model import * # my own model implementation, in the same directory

# %% [markdown]
# # Compile model (configure learning process)

# %%
input_shape = (160, 320, 3) # sample_image   (160, 320, 3)
model = get_custom_model(input_shape)
model.summary()
# Before training a model, you need to configure the learning process, which is done via the compile method.
# 
# keras.optimizers.Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=1e-08, decay=0.0)

optimizer="adam" # 'sgd' | 'rmsprop'
loss_function="mse" # | 'binary_crossentropy' | 'mse' | mean_squared_error | sparse_categorical_crossentropy
metrics_array=['accuracy'] # , mean_pred, false_rates

model.compile(optimizer, loss_function, metrics_array)
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# lambda_1 (Lambda)                (None, 160, 320, 3)   0           lambda_input_1[0][0]
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)  (None, 160, 320, 32)  896         lambda_1[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)              (None, 1638400)       0           convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 256)           419430656   flatten_1[0][0]
# ____________________________________________________________________________________________________
# Dropout_0.25_01 (Dropout)        (None, 256)           0           dense_1[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                  (None, 1)             257         Dropout_0.25_01[0][0]
# ====================================================================================================
# Total params: 419,431,809
# Trainable params: 419,431,809
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %% [markdown]
# # Replace model with one stored on disk
#
# - If you replace the model, the INPUT dimetions have to be the same as these trained
# - Name your models well

# %% [raw]
# from keras.models import load_model
#
# if should_retrain_existing_model:
#     model_path = model_dir + model_to_continue_training
#     model = load_model(model_path)
#     model.summary()

# %% [markdown]
# # Define yield Generator

# %%
from generator import * # my own implementation of yield generator, same directory

# %%
train_generator = generator(training, DATA_DIR, YIELD_BATCH_SIZE)
validation_generator = generator(testing, DATA_DIR, YIELD_BATCH_SIZE)

# %% [markdown]
# # Train (fit) the model agaist given labels
#
# https://keras.io/models/sequential/
#
#
# - steps_per_epoch:
# Total number of steps (batches of samples) to yield from generator before declaring one epoch finished and starting the next epoch. It should typically be equal to the number of unique samples if your dataset divided by the batch size.
#
# - initial_epoch: Epoch at which to start training (useful for resuming a previous training run)

# %%
history = model.fit_generator(train_generator,
                              samples_per_epoch = len(training), 
                              nb_epoch = RUN_EPOCHS, 
                              validation_data = validation_generator, 
                              nb_val_samples = len(validation), 
                              verbose = 0)
# Out:
# batch 0 ) size: 256 index 0 to 256 of 2765
# batch 1 ) size: 256 index 256 to 512 of 2765
# batch 2 ) size: 256 index 512 to 768 of 2765
# batch 3 ) size: 256 index 768 to 1024 of 2765
# batch 4 ) size: 256 index 1024 to 1280 of 2765
# batch 5 ) size: 256 index 1280 to 1536 of 2765
# batch 6 ) size: 256 index 1536 to 1792 of 2765
# batch 7 ) size: 256 index 1792 to 2048 of 2765
# batch 8 ) size: 256 index 2048 to 2304 of 2765
# batch 9 ) size: 256 index 2304 to 2560 of 2765
# batch 10 ) size: 205 index 2560 to 2765 of 2765
# batch 11 ) size: 256 index 0 to 256 of 2765
# batch 12 ) size: 256 index 256 to 512 of 2765
# batch 13 ) size: 256 index 512 to 768 of 2765
# batch 14 ) size: 256 index 768 to 1024 of 2765
# batch 15 ) size: 256 index 1024 to 1280 of 2765
# batch 16 ) size: 256 index 1280 to 1536 of 2765
# batch 17 ) size: 256 index 1536 to 1792 of 2765
# batch 18 ) size: 256 index 1792 to 2048 of 2765
# batch 19 ) size: 256 index 2048 to 2304 of 2765
# batch 20 ) size: 256 index 2304 to 2560 of 2765
# batch 0 ) size: 256 index 0 to 256 of 1206
# batch 1 ) size: 256 index 256 to 512 of 1206
# batch 2 ) size: 256 index 512 to 768 of 1206
# batch 3 ) size: 256 index 768 to 1024 of 1206
# batch 4 ) size: 182 index 1024 to 1206 of 1206
# batch 5 ) size: 256 index 0 to 256 of 1206
# batch 6 ) size: 256 index 256 to 512 of 1206
# batch 7 ) size: 256 index 512 to 768 of 1206
# batch 8 ) size: 256 index 768 to 1024 of 1206
# batch 9 ) size: 182 index 1024 to 1206 of 1206
# batch 10 ) size: 256 index 0 to 256 of 1206
# batch 11 ) size: 256 index 256 to 512 of 1206
# batch 12 ) size: 256 index 512 to 768 of 1206
# batch 13 ) size: 256 index 768 to 1024 of 1206
# batch 21 ) size: 205 index 2560 to 2765 of 2765
# batch 22 ) size: 256 index 0 to 256 of 2765
# batch 23 ) size: 256 index 256 to 512 of 2765
# batch 24 ) size: 256 index 512 to 768 of 2765
# batch 25 ) size: 256 index 768 to 1024 of 2765
# batch 26 ) size: 256 index 1024 to 1280 of 2765
# batch 27 ) size: 256 index 1280 to 1536 of 2765
# batch 28 ) size: 256 index 1536 to 1792 of 2765
# batch 29 ) size: 256 index 1792 to 2048 of 2765
# batch 30 ) size: 256 index 2048 to 2304 of 2765
# batch 31 ) size: 256 index 2304 to 2560 of 2765
# batch 14 ) size: 182 index 1024 to 1206 of 1206
# batch 15 ) size: 256 index 0 to 256 of 1206
# batch 16 ) size: 256 index 256 to 512 of 1206
# batch 17 ) size: 256 index 512 to 768 of 1206
# batch 18 ) size: 256 index 768 to 1024 of 1206
# batch 19 ) size: 182 index 1024 to 1206 of 1206
# batch 20 ) size: 256 index 0 to 256 of 1206
# batch 21 ) size: 256 index 256 to 512 of 1206
# batch 22 ) size: 256 index 512 to 768 of 1206
# batch 23 ) size: 256 index 768 to 1024 of 1206
# batch 24 ) size: 182 index 1024 to 1206 of 1206
# batch 25 ) size: 256 index 0 to 256 of 1206
# batch 26 ) size: 256 index 256 to 512 of 1206
# batch 27 ) size: 256 index 512 to 768 of 1206
# batch 32 ) size: 205 index 2560 to 2765 of 2765
# batch 33 ) size: 256 index 0 to 256 of 2765
# batch 34 ) size: 256 index 256 to 512 of 2765
# batch 35 ) size: 256 index 512 to 768 of 2765
# batch 36 ) size: 256 index 768 to 1024 of 2765
# batch 37 ) size: 256 index 1024 to 1280 of 2765
# batch 38 ) size: 256 index 1280 to 1536 of 2765
# batch 39 ) size: 256 index 1536 to 1792 of 2765
# batch 40 ) size: 256 index 1792 to 2048 of 2765
# batch 41 ) size: 256 index 2048 to 2304 of 2765
# batch 42 ) size: 256 index 2304 to 2560 of 2765
# batch 28 ) size: 256 index 768 to 1024 of 1206
# batch 29 ) size: 182 index 1024 to 1206 of 1206
# batch 30 ) size: 256 index 0 to 256 of 1206
# batch 31 ) size: 256 index 256 to 512 of 1206
# batch 32 ) size: 256 index 512 to 768 of 1206
# batch 33 ) size: 256 index 768 to 1024 of 1206
# batch 34 ) size: 182 index 1024 to 1206 of 1206
# batch 35 ) size: 256 index 0 to 256 of 1206
# batch 36 ) size: 256 index 256 to 512 of 1206
# batch 37 ) size: 256 index 512 to 768 of 1206
# batch 38 ) size: 256 index 768 to 1024 of 1206
# batch 39 ) size: 182 index 1024 to 1206 of 1206
# batch 40 ) size: 256 index 0 to 256 of 1206
# batch 41 ) size: 256 index 256 to 512 of 1206
# batch 43 ) size: 205 index 2560 to 2765 of 2765
# batch 44 ) size: 256 index 0 to 256 of 2765
# batch 45 ) size: 256 index 256 to 512 of 2765
# batch 46 ) size: 256 index 512 to 768 of 2765
# batch 47 ) size: 256 index 768 to 1024 of 2765
# batch 48 ) size: 256 index 1024 to 1280 of 2765
# batch 49 ) size: 256 index 1280 to 1536 of 2765
# batch 50 ) size: 256 index 1536 to 1792 of 2765
# batch 51 ) size: 256 index 1792 to 2048 of 2765
# batch 52 ) size: 256 index 2048 to 2304 of 2765
# batch 53 ) size: 256 index 2304 to 2560 of 2765
# batch 42 ) size: 256 index 512 to 768 of 1206
# batch 43 ) size: 256 index 768 to 1024 of 1206
# batch 44 ) size: 182 index 1024 to 1206 of 1206
# batch 45 ) size: 256 index 0 to 256 of 1206
# batch 46 ) size: 256 index 256 to 512 of 1206
# batch 47 ) size: 256 index 512 to 768 of 1206
# batch 48 ) size: 256 index 768 to 1024 of 1206
# batch 49 ) size: 182 index 1024 to 1206 of 1206
# batch 50 ) size: 256 index 0 to 256 of 1206
# batch 51 ) size: 256 index 256 to 512 of 1206
# batch 52 ) size: 256 index 512 to 768 of 1206
# batch 53 ) size: 256 index 768 to 1024 of 1206
# batch 54 ) size: 182 index 1024 to 1206 of 1206
# batch 55 ) size: 256 index 0 to 256 of 1206
# batch 54 ) size: 205 index 2560 to 2765 of 2765
# batch 55 ) size: 256 index 0 to 256 of 2765
# batch 56 ) size: 256 index 256 to 512 of 2765
# batch 57 ) size: 256 index 512 to 768 of 2765
# batch 58 ) size: 256 index 768 to 1024 of 2765
# batch 59 ) size: 256 index 1024 to 1280 of 2765
# batch 60 ) size: 256 index 1280 to 1536 of 2765
# batch 61 ) size: 256 index 1536 to 1792 of 2765
# batch 62 ) size: 256 index 1792 to 2048 of 2765
# batch 63 ) size: 256 index 2048 to 2304 of 2765
# batch 64 ) size: 256 index 2304 to 2560 of 2765
# batch 56 ) size: 256 index 256 to 512 of 1206
# batch 57 ) size: 256 index 512 to 768 of 1206
# batch 58 ) size: 256 index 768 to 1024 of 1206
# batch 59 ) size: 182 index 1024 to 1206 of 1206
# batch 60 ) size: 256 index 0 to 256 of 1206
# batch 61 ) size: 256 index 256 to 512 of 1206
# batch 62 ) size: 256 index 512 to 768 of 1206
# batch 63 ) size: 256 index 768 to 1024 of 1206
# batch 64 ) size: 182 index 1024 to 1206 of 1206
# batch 65 ) size: 256 index 0 to 256 of 1206
# batch 66 ) size: 256 index 256 to 512 of 1206
# batch 67 ) size: 256 index 512 to 768 of 1206
# batch 68 ) size: 256 index 768 to 1024 of 1206
# batch 69 ) size: 182 index 1024 to 1206 of 1206

# %% [raw]
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# conv2d_1_relu (Convolution2D)    (None, 160, 320, 32)  896         convolution2d_input_1[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)              (None, 1638400)       0           conv2d_1_relu[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 1)             1638401     flatten_1[0][0]
# ====================================================================================================
# Total params: 1,639,297
# Trainable params: 1,639,297
# Non-trainable params: 0
#
# training_features.shape 590
# Train on 472 samples, validate on 118 samples
# - MacBook Pro CPU 13s / epoch
# - MacBook Pro GPU 5s / epoch
#
#
#
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# conv2d_1_relu (Convolution2D)    (None, 160, 320, 32)  896         convolution2d_input_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_3_relu (Convolution2D)    (None, 160, 320, 32)  25632       conv2d_1_relu[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)              (None, 1638400)       0           conv2d_3_relu[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 1)             1638401     flatten_1[0][0]
# ====================================================================================================
# Total params: 1,664,929
# Trainable params: 1,664,929
# Non-trainable params: 0
#
#
# training_features.shape 590
# Train on 472 samples, validate on 118 samples
# - MacBook Pro CPU 114s / epoch
# - MacBook Pro GPU 29s / epoch (29%)
#
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# conv2d_1_relu (Convolution2D)    (None, 160, 320, 32)  896         convolution2d_input_1[0][0]
# ____________________________________________________________________________________________________
# conv2d_2_relu (Convolution2D)    (None, 160, 320, 32)  9248        conv2d_1_relu[0][0]
# ____________________________________________________________________________________________________
# conv2d_3_relu (Convolution2D)    (None, 160, 320, 32)  25632       conv2d_2_relu[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)              (None, 1638400)       0           conv2d_3_relu[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 1)             1638401     flatten_1[0][0]
# ====================================================================================================
# Total params: 1,674,177
# Trainable params: 1,674,177
# Non-trainable params: 0
#
# Train on 472 samples, validate on 118 samples
# - MacBook Pro CPU 156s / epoch
# - MacBook Pro GPU ResourceExhaustedError

# %%
# list all data in history
print(history.history.keys())

index = RUN_EPOCHS - 1

training_accuracy = str( history.history['acc'][index])
print("training_accuracy", training_accuracy)

training_error = str( history.history['loss'][index])
print("training_error", training_error)

validation_accuracy = str( history.history['val_acc'][index])
print("validation_accuracy", validation_accuracy)

validation_error = str( history.history['val_loss'][index])
print("validation_error", validation_error)
# Out:
# dict_keys(['val_acc', 'val_loss', 'acc', 'loss'])
# training_accuracy 0.0
# training_error 0.0358069204037
# validation_accuracy 0.543157893482
# validation_error 0.0171807768666

# %% [markdown]
# # Save the model

# %%
# creates a HDF5 file '___.h5'
model.save(DATA_DIR 
           + "model_epoch_" + str(RUN_EPOCHS + RUN_EPOCHS_PREVIOUSLY) 
           + "_val_acc_" + str(validation_accuracy) 
           + ".h5") 
#del model  # deletes the existing model
#model = load_model('my_model.h5')

# %% [markdown]
# # summarize history for accuracy

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy (bigger better)')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['training accuracy', 'testing accuracy'], loc='lower right')
plt.show()

# %% [markdown]
# # summarize history for loss

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Validation error (smaller better)')
plt.ylabel('error')
plt.xlabel('epochs run')
plt.legend(['training error(loss)', 'validation error (loss)'], loc='upper right')
plt.show()

# %% [markdown]
# # Prediction

# %%
from keras.models import load_model

model_path = DATA_DIR + SAVED_MODEL
print(model_path)

model = load_model(model_path) 
model.summary()
# Out:
# ../_DATA/CarND/p3_behavioral_cloning/set_000/model_epoch_5_val_acc_0.543157893482.h5
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# lambda_1 (Lambda)                (None, 160, 320, 3)   0           lambda_input_2[0][0]
# ____________________________________________________________________________________________________
# convolution2d_1 (Convolution2D)  (None, 160, 320, 32)  896         lambda_1[0][0]
# ____________________________________________________________________________________________________
# flatten_1 (Flatten)              (None, 1638400)       0           convolution2d_1[0][0]
# ____________________________________________________________________________________________________
# dense_1 (Dense)                  (None, 256)           419430656   flatten_1[0][0]
# ____________________________________________________________________________________________________
# Dropout_0.25_01 (Dropout)        (None, 256)           0           dense_1[0][0]
# ____________________________________________________________________________________________________
# dense_2 (Dense)                  (None, 1)             257         Dropout_0.25_01[0][0]
# ====================================================================================================
# Total params: 419,431,809
# Trainable params: 419,431,809
# Non-trainable params: 0
# ____________________________________________________________________________________________________

# %%
original_steering_angle = -0.9426954
image_path =  DATA_DIR + "IMG/left_2016_12_01_13_39_28_024.jpg"
print(image_path)

from ImageHelper import read_image_array, read_image_binary
#image = read_image_array(image_path)
image = np.array(read_image_binary(image_path))
#print(image.shape)
plt.imshow(image, cmap='gray')
plt.show()
# Out:
# ../_DATA/CarND/p3_behavioral_cloning/set_000/IMG/left_2016_12_01_13_39_28_024.jpg

# %% [markdown]
# ## Run model.predict(image)

# %%
predictions = model.predict( image[None, :, :], 
                            batch_size = 1, 
                            verbose = 1)
# Out:
# 1/1 [==============================] - 8s

# %% [markdown]
# # Extract top prediction

# %%
from DataHelper import predict_class

percentages = predictions[0]
print("percentages:", percentages)
print("original steering angle:", original_steering_angle)
# Out:
# percentages: [ 0.00319509]
# original steering angle: -0.9426954
